# %%
import numpy as np
from src.models.models import UNet,PSPNet, SegNet, DeepLab
from src.models.train_model import train_unet, train_pspnet, train_segnet, train_deeplab
from src.data.make_dataset import Dataset
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## UNET MODEL

# %%
unet = train_unet()
unet.build(input_shape=(None,224,224,3))
unet.model().summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# model (Functional)              [(None, 224, 224, 64 7635264     input_2[0][0]
# __________________________________________________________________________________________________
# cnn_block (CNNBlock)            (None, 14, 14, 1024) 4723712     model[0][4]
# __________________________________________________________________________________________________
# cnn_block_1 (CNNBlock)          (None, 14, 14, 1024) 9442304     cnn_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 28, 28, 512)  2097664     cnn_block_1[0][0]
# ...

# %%
plot_model(unet.model(), show_shapes=True)

# %% [markdown]
# ## SegNet

# %%
segnet = train_segnet()
segnet.build(input_shape=(None,224,224,3))
segnet.model().summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_13 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# model_11 (Functional)           [(None, 224, 224, 64 14714688    input_13[0][0]
# __________________________________________________________________________________________________
# block_layer_10 (BlockLayer)     (None, 14, 14, 512)  7085568     model_11[0][5]
#                                                                  model_11[0][4]
# __________________________________________________________________________________________________
# block_layer_11 (BlockLayer)     (None, 28, 28, 256)  2363136     block_layer_10[0][0]
#                                                                  model_11[0][3]
# ...

# %%
plot_model(segnet.model(), show_shapes=True)

# %% [markdown]
# ## PSPNet

# %%
pspnet = train_pspnet()
pspnet.build(input_shape=(None,224,224,3))
pspnet.model().summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_17 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# model_15 (Functional)           [(None, 224, 224, 64 7635264     input_17[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 14, 14, 1024) 525312      model_15[0][4]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 14, 14, 1024) 2098176     model_15[0][4]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 14, 14, 1024) 4719616     model_15[0][4]
# ...

# %%
plot_model(pspnet.model(), show_shapes=True)

# %% [markdown]
# ## DeepLab

# %%
model  = train_deeplab()
model.build(input_shape=(None,224,224,3))
model.model().summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_15 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# cnn_block_52 (CNNBlock)         (None, 224, 224, 64) 2048        input_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  multiple             0           cnn_block_52[0][0]
#                                                                  conv2d_104[0][0]
# __________________________________________________________________________________________________
# cnn_block_53 (CNNBlock)         (None, 112, 112, 128 74368       max_pooling2d_5[0][0]
# ...

# %%
plot_model(model.model(), show_shapes=True)

# %%
from 
dataset = Dataset(root_dir=ROOT_DIR,
                      batch_size=1, validation=True)

    train_dataset, validation_dataset, test_dataset = dataset.make()
